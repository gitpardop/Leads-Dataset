# %% [markdown]
# # Leads Dataset Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('C:/Users/Usuario/Desktop/Python_v2/Leads_Dataset/')

import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import plotly.express as px
from dash.dependencies import Input, Output

gris = '#939EBF'
azul_claro = '#99CFFF'
azul_verdoso = '#0097B3'
azul_oscuro = '#2B2880'
naranja = '#F0573E'
paleta_fer = [ azul_claro, gris,azul_oscuro, azul_verdoso, naranja]
customPalette = sns.set_palette(sns.color_palette(paleta_fer))

# %%
df = pd.read_csv('../Leads_Dataset/SampleData.csv')
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,44,53,77,97) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                                Prospect ID  Lead Number Company  \
# 0     7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737     NaN
# 1     2a272436-5132-4136-86fa-dcc88c88f482       660728     NaN
# 2     8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727     NaN
# 3     0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719     NaN
# 4     3256f628-e534-4826-9d63-4a8b88782852       660681     NaN
# ...                                    ...          ...     ...
# 9235  19d6451e-fcd6-407c-b83b-48e1af805ea9       579564     NaN
# 9236  82a7005b-7196-4d56-95ce-a79f937a158d       579546     NaN
# 9237  aac550fe-a586-452d-8d3c-f1b62c94e02c       579545     NaN
# 9238  5330a7d1-2f2b-4df4-85d6-64ca2f6b95b9       579538     NaN
# 9239  571b5c8e-a5b2-4d57-8574-f2ffb06fdeff       579533     NaN
#
#                   Lead Origin Mobile Number Website  Time Zone Job Title  \
# 0                         API           NaN     NaN        NaN       NaN
# ...

# %%
app = dash.Dash()


app.layout = html.Div(children=[
    html.H1(children='Primera prueba dash'),
    dcc.Dropdown(
        id="dropdown",
        options=[{"label": x, "value": x} for x in df.columns],
        value=df.columns[3],
        clearable=False,
    ),
    dcc.Graph(
        id='primer-graf')
])

@app.callback(
    Output("primer-graf", "figure"), 
    [Input("dropdown", "value")])

def update_histogram(column):
    fig = px.histogram(df, x= column,   template = 'simple_white',  color_discrete_sequence=paleta_fer )
    return fig

app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [25/Oct/2021 16:02:58] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2021 16:02:58] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2021 16:02:58] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2021 16:02:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2021 16:03:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Oct/2021 16:03:13] "POST /_dash-update-component HTTP/1.1" 200 -
